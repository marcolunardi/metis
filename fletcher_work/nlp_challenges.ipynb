# %% [markdown]
# # NLP Challenges
#
# ## Challenge 1
#
# Calculate the tf-idf for each word in the first 100 reviews in the nltk movie reviews corpus. For each document, print the top 10 tf-idf words.
#
# ## Challenge 2
#
# Create a mongo collection of tweets about something (Using the twitter API, make a search and get at least 500 tweets). Each mongo document should contain the text, username, favorite count and retweet count of the tweet.
#
# Calculate the tf-idf for each word in the tweets you uploaded to your mongodb. For each tweet, print the highest tf-idf term. What are potential problems when trying to calculate tf-idf on really short documents like tweets?

# %%
import nltk
from nltk.tokenize import sent_tokenize
from nltk.tokenize import TreebankWordTokenizer
from nltk.tokenize import word_tokenize
from nltk.tokenize import wordpunct_tokenize
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk
from nltk.corpus import treebank_chunk
from textblob import TextBlob
import pymongo
from nltk.corpus import stopwords
from nltk.corpus import movie_reviews
from nltk.util import ngrams
from nltk.tokenize import sent_tokenize, word_tokenize
from collections import defaultdict
from operator import itemgetter
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from __future__ import division, unicode_literals

# %% [markdown]
# ## Challenge 1

# %%
fileids = movie_reviews.fileids()[:100]
doc_words = [movie_reviews.words(fileid) for fileid in fileids]
documents = [' '.join(words) for words in doc_words]
print documents[:1]
# Out:
# [u'plot : two teen couples go to a church party , drink and then drive . they get into an accident . one of the guys dies , but his girlfriend continues to see him in her life , and has nightmares . what \' s the deal ? watch the movie and " sorta " find out . . . critique : a mind - fuck movie for the teen generation that touches on a very cool idea , but presents it in a very bad package . which is what makes this review an even harder one to write , since i generally applaud films which attempt to break the mold , mess with your head and such ( lost highway & memento ) , but there are good and bad ways of making all types of films , and these folks just didn \' t snag this one correctly . they seem to have taken this pretty neat concept , but executed it terribly . so what are the problems with the movie ? well , its main problem is that it \' s simply too jumbled . it starts off " normal " but then downshifts into this " fantasy " world in which you , as an audience member , have no idea what \' s going on . there are dreams , there are characters coming back from the dead , there are others who look like the dead , there are strange apparitions , there are disappearances , there are a looooot of chase scenes , there are tons of weird things that happen , and most of it is simply not explained . now i personally don \' t mind trying to unravel a film every now and then , but when all it does is give me the same clue over and over again , i get kind of fed up after a while , which is this film \' s biggest problem . it \' s obviously got this big secret to hide , but it seems to want to hide it completely until its final five minutes . and do they make things entertaining , thrilling or even engaging , in the meantime ? not really . the sad part is that the arrow and i both dig on flicks like this , so we actually figured most of it out by the half - way point , so all of the strangeness after that did start to make a little bit of sense , but it still didn \' t the make the film all that more entertaining . i guess the bottom line with movies like this is that you should always make sure that the audience is " into it " even before they are given the secret password to enter your world of understanding . i mean , showing melissa sagemiller running away from visions for about 20 minutes throughout the movie is just plain lazy ! ! okay , we get it . . . there are people chasing her and we don \' t know who they are . do we really need to see it over and over again ? how about giving us different scenes offering further insight into all of the strangeness going down in the movie ? apparently , the studio took this film away from its director and chopped it up themselves , and it shows . there might \' ve been a pretty decent teen mind - fuck movie in here somewhere , but i guess " the suits " decided that turning it into a music video with little edge , would make more sense . the actors are pretty good for the most part , although wes bentley just seemed to be playing the exact same character that he did in american beauty , only in a new neighborhood . but my biggest kudos go out to sagemiller , who holds her own throughout the entire film , and actually has you feeling her character \' s unraveling . overall , the film doesn \' t stick because it doesn \' t entertain , it \' s confusing , it rarely excites and it feels pretty redundant for most of its runtime , despite a pretty cool ending and explanation to all of the craziness that came before it . oh , and by the way , this is not a horror or teen slasher flick . . . it \' s just packaged to look that way because someone is apparently assuming that the genre is still hot with the kids . it also wrapped production two years ago and has been sitting on the shelves ever since . whatever . . . skip it ! where \' s joblo coming from ? a nightmare of elm street 3 ( 7 / 10 ) - blair witch 2 ( 7 / 10 ) - the crow ( 9 / 10 ) - the crow : salvation ( 4 / 10 ) - lost highway ( 10  ...

# %%
vectorizer = TfidfVectorizer(stop_words="english")
doc_vectors = vectorizer.fit_transform(documents)

# %%
print doc_vectors.sorted_indices()
# Out:
#   (0, 1)	0.44936766757
#   (0, 63)	0.0464853185254
#   (0, 140)	0.0482409217244
#   (0, 174)	0.0309889588951
#   (0, 180)	0.063009225981
#   (0, 257)	0.0435515399973
#   (0, 344)	0.0365751081881
#   (0, 432)	0.0764413797476
#   (0, 433)	0.0647116154826
#   (0, 443)	0.0647116154826
#   (0, 496)	0.0647116154826
#   (0, 555)	0.0593807653591
#   (0, 576)	0.0382206898738
#   (0, 591)	0.0519992426525
#   (0, 627)	0.065201744407
#   (0, 652)	0.0447829290238
#   (0, 747)	0.0647116154826
#   (0, 791)	0.0647116154826
#   (0, 810)	0.0250005970613
#   (0, 813)	0.105329376952
#   (0, 836)	0.0358236182784
#   (0, 847)	0.0482409217244
#   (0, 987)	0.0411544684019
#   (0, 1126)	0.0526646884759
#   (0, 1273)	0.0399887858332
#   :	:
#   (99, 7954)	0.0484846882083
#   (99, 7971)	0.0466303532075
#   (99, 7973)	0.0280725548633
#   (99, 7974)	0.0400948510068
#   (99, 8044)	0.051185612515
#   (99, 8165)	0.0546677095664
#   (99, 8185)	0.0757760703269
#   (99, 8201)	0.0595754497165
#   (99, 8220)	0.0484846882083
#   (99, 8250)	0.0595754497165
#   (99, 8262)	0.0595754497165
#   (99, 8345)	0.0595754497165
#   (99, 8414)	0.0595754497165
#   (99, 8434)	0.0400948510068
#   (99, 8465)	0.0595754497165
#   (99, 8474)	0.034405938112
#   (99, 8518)	0.0413701322149
#   (99, 8566)	0.0595754497165
#   (99, 8572)	0.0369192001088
#   (99, 8592)	0.0546677095664
#   (99, 8616)	0.0201395257058
#   (99, 8762)	0.0400948510068
#   (99, 8772)	0.0803918209657
#   (99, 8817)	0.119150899433
#   (99, 8825)	0.0544152344817

# %%
print type(vectorizer)
# Out:
# <class 'sklearn.feature_extraction.text.TfidfVectorizer'>

# %%
d = dict(zip(vectorizer.get_feature_names(), doc_vectors.data))
d.keys()
# Out:
# [u'raining',
#  u'foul',
#  u'finesses',
#  u'hanging',
#  u'francesca',
#  u'gabrielle',
#  u'grenier',
#  u'originality',
#  u'fingernails',
#  u'caned',
#  u'rickman',
#  u'immature',
#  u'parallax',
#  u'sinking',
#  u'hormone',
#  u'hacked',
#  u'regional',
#  u'stabber',
#  u'leisurely',
#  u'bringing',
#  u'differentiated',
#  u'basics',
#  u'prize',
#  u'wooden',
#  u'solid',
#  u'crotch',
#  u'succession',
#  u'stereotypical',
#  u'straight',
#  u'knell',
#  u'nigh',
#  u'tired',
#  u'miller',
#  u'bacon',
#  u'pulse',
#  u'tires',
#  u'renfro',
#  u'second',
#  u'valiant',
#  u'woody',
#  u'allayah',
#  u'loathing',
#  u'quite',
#  u'admire',
#  u'characterless',
#  u'ruthless',
#  u'thunder',
#  u'cooking',
#  u'grossie',
#  u'joely',
#  u'groupie',
#  u'succumb',
#  u'specialist',
#  u'hero',
#  u'dahl',
#  u'reporter',
#  u'herc',
#  u'47',
#  u'china',
#  u'cult',
#  u'dork',
#  u'conversational',
#  u'kids',
#  u'elaborate',
#  u'incriminates',
#  u'robin',
#  u'military',
#  u'criticism',
#  u'appropriately',
#  u'cobblers',
#  u'mortensen',
#  u'explained',
#  u'replace',
#  u'brought',
#  u'interupts',
#  u'stern',
#  u'cocaine',
#  u'opponents',
#  u'cheating',
#  u'dna',
#  u'occupying',
#  u'music',
#  u'strike',
#  u'holy',
#  u'relax',
#  u'detracts',
#  u'brings',
#  u'20th',
#  u'hurt',
#  u'98',
#  u'90',
#  u'93',
#  u'hold',
#  u'95',
#  u'94',
#  u'circumstances',
#  u'virtuous',
#  u'stairs',
#  u'famed',
#  u'blade',
#  u'burnett',
#  u'revenues',
#  u'example',
#  u'household',
#  u'dragons',
#  u'currency',
#  u'reviewing',
#  u'want',
#  u'gargantuan',
#  u'absolute',
#  u'travel',
#  u'damage',
#  u'machine',
#  u'hot',
#  u'epinions',
#  u'machina',
#  u'significance',
#  u'cheetah',
#  u'classify',
#  u'beauty',
#  u'swing',
#  u'pimps',
#  u'wrong',
#  u'hurricaine',
#  u'steadfast',
#  u'sioux',
#  u'effective',
#  u'cheri',
#  u'subplots',
#  u'sickening',
#  u'keeps',
#  u'nonsensical',
#  u'wing',
#  u'wind',
#  u'sprawling',
#  u'welcomed',
#  u'dreamed',
#  u'resumes',
#  u'receiver',
#  u'conned',
#  u'reprises',
#  u'fit',
#  u'heretofore',
#  u'fix',
#  u'survivors',
#  u'rescued',
#  u'distinguishing',
#  u'fig',
#  u'hidden',
#  u'admirable',
#  u'easier',
#  u'grievous',
#  u'lambert',
#  u'effects',
#  u'silver',
#  u'scholar',
#  u'represents',
#  u'debut',
#  u'arrow',
#  u'addicted',
#  u'volcano',
#  u'interfering',
#  u'preceded',
#  u'series',
#  u'bowls',
#  u'precedes',
#  u'ring',
#  u'syd',
#  u'mason',
#  u'rd',
#  u'engineer',
#  u'strategist',
#  u'differentiates',
#  u'rented',
#  u'clarence',
#  u'assured',
#  u'fugitive',
#  u'enormous',
#  u'bates',
#  u'exposing',
#  u'shelves',
#  u'atm',
#  u'ups',
#  u'shelved',
#  u'disturbed',
#  u'guttenberg',
#  u'tempting',
#  u'1970s',
#  u'swoons',
#  u'thankless',
#  u'juergen',
#  u'nigel',
#  u'subtlety',
#  u'nosebleeds',
#  u'wash',
#  u'seinfeld',
#  u'wasn',
#  u'175',
#  u'clarity',
#  u'sutherland',
#  u'bitten',
#  u'olds',
#  u'basketball',
#  u'service',
#  u'spiers',
#  u'engagement',
#  u'needed',
#  u'master',
#  u'listed',
#  u'legs',
#  u'bitter',
#  u'ranging',
#  u'stupidity',
#  u'hewitt',
#  u'rewards',
#  u'collapse',
#  u'predictably',
#  u'asner',
#  u'wisdom',
#  u'task',
#  u'predictable',
#  u'_the',
#  u'crawl',
#  u'trek',
#  u'showed',
#  u'outlaw',
#  u'tree',
#  u'project',
#  u'idle',
#  u'sheen',
#  u'bodyguards',
#  u'feeling',
#  u'groaning',
#  u'fevered',
#  u'longs',
#  u'boston',
#  u'corny',
#  u'constricted',
#  u'dozen',
#  u'gators',
#  u'wholesome',
#  u'responsible',
#  u'causing',
#  u'amusing',
#  u'doors',
#  u'season',
#  u'reelection',
#  u'committing',
#  u'furrier',
#  u'shall',
#  u'thrilled',
#  u'overscore',
#  u'object',
#  u'cinematic',
#  u'resonates',
#  u'mouth',
#  u'addict',
#  u'welle',
#  u'thriller',
#  u'morality',
#  u'singer',
#  u'episode',
#  u'released',
#  u'professor',
#  u'camp',
#  u'drunks',
#  u'tech',
#  u'scream',
#  u'came',
#  u'marvel',
#  u'incorporate',
#  u'boogie',
#  u'bomb',
#  u'nominated',
#  u'fingers',
#  u'gauge',
#  u'participate',
#  u'lethal',
#  u'tempted',
#  u'vindictive',
#  u'parodies',
#  u'touches',
#  u'busy',
#  u'headline',
#  u'menu',
#  u'bust',
#  u'regurgitated',
#  u'theme',
#  u'bliss',
#  u'rick',
#  u'rich',
#  u'heartily',
#  u'pickens',
#  u'mena',
#  u'godzilla',
#  u'ney',
#  u'platt',
#  u'rosebudd',
#  u'clumsiness',
#  u'reversal',
#  u'altogether',
#  u'lurches',
#  u'nicely',
#  u'patch',
#  u'greene',
#  u'flanked',
#  u'release',
#  u'atomic',
#  u'respond',
#  u'mandatory',
#  u'disaster',
#  u'fair',
#  u'slashfest',
#  u'goodnight',
#  u'result',
#  u'delores',
#  u'fail',
#  u'hammer',
#  u'best',
#  u'manson',
#  u'deadpan',
#  u'delro',
#  u'score',
#  u'humankind',
#  u'melissa',
#  u'preserve',
#  u'rundown',
#  u'parallels',
#  u'extend',
#  u'nature',
#  u'rolled',
#  u'twinkling',
#  u'extent',
#  u'carbon',
#  u'debt',
#  u'roller',
#  u'tyranny',
#  u'accident',
#  u'sacrificing',
#  u'reported',
#  u'country',
#  u'adventures',
#  u'edgar',
#  u'planned',
#  u'logic',
#  u'installments',
#  u'argue',
#  u'adapted',
#  u'asked',
#  u'rehash',
#  u'munches',
#  u'kurosawa',
#  u'canyon',
#  u'pregnancy',
#  u'blonde',
#  u'cardboard',
#  u'billing',
#  u'synchronicity',
#  u'extraction',
#  u'startled',
#  u'superhuman',
#  u'counterattack',
#  u'natured',
#  u'life',
#  u'sydney',
#  u'eastern',
#  u'arkin',
#  u'worker',
#  u'athos',
#  u'almasy',
#  u'dave',
#  u'substance',
#  u'reno',
#  u'child',
#  u'worked',
#  u'spin',
#  u'hospitalizes',
#  u'gritty',
#  u'adaptations',
#  u'cheapened',
#  u'dissect',
#  u'professionally',
#  u'sinise',
#  u'employ',
#  u'opulence',
#  u'snorks',
#  u'detmer',
#  u'played',
#  u'weirdness',
#  u'letdown',
#  u'player',
#  u'australia',
#  u'madonna',
#  u'damaged',
#  u'hokey',
#  u'portobello',
#  u'things',
#  u'yellow',
#  u'demands',
#  u'feuding',
#  u'harmony',
#  u'babies',
#  u'european',
#  u'fairly',
#  u'spying',
#  u'cindy',
#  u'issac',
#  u'stiffs',
#  u'ownership',
#  u'tune',
#  u'blofeld',
#  u'lucas',
#  u'dre',
#  u'echoed',
#  u'echoes',
#  u'eroticism',
#  u'gigolo',
#  u'sleeps',
#  u'golden',
#  u'bernt',
#  u'slayings',
#  u'disguise',
#  u'plight',
#  u'bit',
#  u'amusingly',
#  u'previous',
#  u'enters',
#  u'hal',
#  u'han',
#  u'ease',
#  u'macdonald',
#  u'beloved',
#  u'prison',
#  u'east',
#  u'hat',
#  u'preciously',
#  u'quirk',
#  u'possible',
#  u'possibly',
#  u'birth',
#  u'pertinent',
#  u'poses',
#  u'desire',
#  u'bobby',
#  u'seaside',
#  u'hooey',
#  u'remind',
#  u'prologue',
#  u'battlefield',
#  u'right',
#  u'old',
#  u'crowd',
#  u'people',
#  u'macabre',
#  u'crown',
#  u'dorian',
#  u'fox',
#  u'creative',
#  u'witty',
#  u'continue',
#  u'exposition',
#  u'summoned',
#  u'foo',
#  u'palatable',
#  u'shakes',
#  u'cheadle',
#  u'shifting',
#  u'starring',
#  u'losing',
#  u'memorable',
#  u'manufacturing',
#  u'shaken',
#  u'dollars',
#  u'citizens',
#  u'slightly',
#  u'dahlings',
#  u'nixon',
#  u'sob',
#  u'statements',
#  u'maxwell',
#  u'marshall',
#  u'son',
#  u'gojira',
#  u'respectable',
#  u'beings',
#  u'magazines',
#  u'wrap',
#  u'shoots',
#  u'support',
#  u'constantly',
#  u'raped',
#  u'absolutely',
#  u'orville',
#  u'joseph',
#  u'jane',
#  u'bollocks',
#  u'trappings',
#  u'launching',
#  u'happy',
#  u'offer',
#  u'understandably',
#  u'hemisphere',
#  u'palmetto',
#  u'squalid',
#  u'congratulations',
#  u'inside',
#  u'devices',
#  u'epps',
#  u'complications',
#  u'lays',
#  u'pontificate',
#  u'smashed',
#  u'palm',
#  u'passenger',
#  u'juvenile',
#  u'proud',
#  u'proved',
#  u'barrymore',
#  u'tournament',
#  u'proven',
#  u'somebody',
#  u'proves',
#  u'exist',
#  u'tooth',
#  u'dealer',
#  u'floor',
#  u'glacier',
#  u'trucker',
#  u'cambodia',
#  u'flood',
#  u'role',
#  u'ambitious',
#  u'conferring',
#  u'smell',
#  u'roll',
#  u'models',
#  u'transported',
#  u'intent',
#  u'explosions',
#  u'spader',
#  u'glass',
#  u'time',
#  u'pecan',
#  u'timm',
#  u'gown',
#  u'newbie',
#  u'chain',
#  u'reviewers',
#  u'crocodile',
#  u'theaters',
#  u'xeroxed',
#  u'chair',
#  u'hole',
#  u'millisecond',
#  u'venice',
#  u'uneven',
#  u'rambling',
#  u'suspending',
#  u'reverting',
#  u'macho',
#  u'paychecks',
#  u'jerk',
#  u'choice',
#  u'stays',
#  u'exact',
#  u'minute',
#  u'cooks',
#  u'knockin',
#  u'ollie',
#  u'minnie',
#  u'leave',
#  u'solved',
#  u'settle',
#  u'aviators',
#  u'team',
#  u'prevent',
#  u'minion',
#  u'sigh',
#  u'sign',
#  u'erotic',
#  u'chopping',
#  u'catatonic',
#  u'anaconda',
#  u'patient',
#  u'nightie',
#  u'headset',
#  u'educate',
#  u'elton',
#  u'jeopardy',
#  u'realizing',
#  u'ragtop',
#  u'current',
#  u'remembered',
#  u'falling',
#  u'unintentionally',
#  u'funeral',
#  u'concepts',
#  u'backwords',
#  u'ratio',
#  u'soundtracks',
#  u'terrence',
#  u'mafioso',
#  u'accomplishes',
#  u'brilliant',
#  u'funded',
#  u'commonly',
#  u'cusack',
#  u'accomplished',
#  u'ineffective',
#  u'love',
#  u'bloods',
#  u'curtailing',
#  u'bloody',
#  u'coinciding',
#  u'fake',
#  u'working',
#  u'positive',
#  u'angry',
#  u'distancing',
#  u'topples',
#  u'opposed',
#  u'wondering',
#  u'films',
#  u'scope',
#  u'loving',
#  u'introducing',
#  u'apparent',
#  u'oregon',
#  u'visual',
#  u'ignorant',
#  u'scratcher',
#  u'scratches',
#  u'lawnmowers',
#  u'easiest',
#  u'behalf',
#  u'incited',
#  u'originally',
#  u'overloaded',
#  u'believes',
#  u'values',
#  u'stature',
#  u'following',
#  u'gunfire',
#  u'kamil',
#  u'mirrors',
#  u'awesome',
#  u'smirnov',
#  u'stoli',
#  u'hides',
#  u'allowed',
#  u'tgif',
#  u'stole',
#  u'evidently',
#  u'listens',
#  u'poking',
#  u'immune',
#  u'elephant',
#  u'coleman',
#  u'remar',
#  u'nell',
#  u'explores',
#  u'spot',
#  u'convincingly',
#  u'pathetic',
#  u'turturro',
#  u'date',
#  u'suck',
#  u'dove',
#  u'narrating',
#  u'brainless',
#  u'egotistical',
#  u'natural',
#  u'jonnie',
#  u'correlate',
#  u'conscious',
#  u'bluster',
#  u'pulled',
#  u'sf',
#  u'se',
#  u'drunken',
#  u'innocuous',
#  u'noteworthy',
#  u'unacceptable',
#  u'kong',
#  u'course',
#  u'episodes',
#  u'jimmy',
#  u'solitary',
#  u'yawning',
#  u'haughty',
#  u'jim',
#  u'troubles',
#  u'methodology',
#  u'attraction',
#  u'covertly',
#  u'creations',
#  u'rupert',
#  u'dwarfs',
#  u'suspension',
#  u'decades',
#  u'brinks',
#  u'crappiness',
#  u'instantly',
#  u'ketchum',
#  u'conveying',
#  u'witchcraft',
#  u'nation',
#  u'records',
#  u'workmanlike',
#  u'arriving',
#  u'skewered',
#  u'ketchup',
#  u'maintaining',
#  u'truckload',
#  u'brody',
#  u'turteltaub',
#  u'fisherman',
#  u'veins',
#  u'square',
#  u'retrieve',
#  u'shuckin',
#  u'crushing',
#  u'irina',
#  u'entering',
#  u'sexually',
#  u'disasters',
#  u'naked',
#  u'imogen',
#  u'rounding',
#  u'sniveling',
#  u'squared',
#  u'stallone',
#  u'seriously',
#  u'investigation',
#  u'firorina',
#  u'internet',
#  u'formula',
#  u'squares',
#  u'ioan',
#  u'bordering',
#  u'dodgers',
#  u'worthiness',
#  u'siege',
#  u'million',
#  u'possibility',
#  u'loyalty',
#  u'complicated',
#  u'intensely',
#  u'grandma',
#  u'scarred',
#  u'marla',
#  u'shores',
#  u'training',
#  u'dunne',
#  u'dunno',
#  u'punk',
#  u'bothersome',
#  u'jumbled',
#  u'emotion',
#  u'henry',
#  u'saving',
#  u'reveals',
#  u'spoken',
#  u'specifically',
#  u'spanish',
#  u'open',
#  u'plotless',
#  u'city',
#  u'boulevard',
#  u'bite',
#  u'indicate',
#  u'teacher',
#  u'stifled',
#  u'types',
#  u'stuffed',
#  u'realization',
#  u'bits',
#  u'williams',
#  u'slasher',
#  u'ashby',
#  u'floppy',
#  u'sentinels',
#  u'surges',
#  u'meddling',
#  u'padding',
#  u'ridiculous',
#  u'review',
#  u'photographic',
#  u'boyfriend',
#  u'iceberg',
#  u'depressed',
#  u'exacted',
#  u'rehab',
#  u'future',
#  u'bauer',
#  u'damned',
#  u'disasterous',
#  u'addressing',
#  u'san',
#  u'nicer',
#  u'sumptuous',
#  u'revolt',
#  u'turned',
#  u'alley',
#  u'sad',
#  u'prestigious',
#  u'say',
#  u'buried',
#  u'uninterrupted',
#  u'allen',
#  u'saw',
#  u'sat',
#  u'sanctimonious',
#  u'aside',
#  u'note',
#  u'maintain',
#  u'destroy',
#  u'ironically',
#  u'opposite',
#  u'discerning',
#  u'knew',
#  u'buffet',
#  u'knee',
#  u'undeserving',
#  u'inserted',
#  u'pages',
#  u'lawn',
#  u'average',
#  u'drive',
#  u'defeating',
#  u'ways',
#  u'atlantic',
#  u'fascinated',
#  u'delroy',
#  u'madison',
#  u'wynn',
#  u'imagines',
#  u'merit',
#  u'bright',
#  u'inconsistent',
#  u'soviets',
#  u'imagined',
#  u'slow',
#  u'reconciling',
#  u'romanian',
#  u'aimlessly',
#  u'tears',
#  u'going',
#  u'equipped',
#  u'caroline',
#  u'carolina',
#  u'remastered',
#  u'beatles',
#  u'psychiatrist',
#  u'showiest',
#  u'assistant',
#  u'cursing',
#  u'simplistic',
#  u'mysticism',
#  u'prime',
#  u'undemanding',
#  u'pimp',
#  u'artist',
#  u'worried',
#  u'priest',
#  u'roger',
#  u'worries',
#  u'uncover',
#  u'ungloriously',
#  u'artistically',
#  u'fable',
#  u'americanized',
#  u'gangster',
#  u'anyways',
#  u'mystics',
#  u'surgery',
#  u'planet',
#  u'wielding',
#  u'ostensibly',
#  u'alarming',
#  u'goers',
#  u'teeny',
#  u'enjoys',
#  u'panache',
#  u'jobs',
#  u'impregnated',
#  u'marvin',
#  u'screen',
#  u'revealed',
#  u'adept',
#  u'concentrate',
#  u'awards',
#  u'menacing',
#  u'spark',
#  u'frisky',
#  u'residence',
#  u'millionaire',
#  u'flipper',
#  u'expression',
#  u'mann',
#  u'twin',
#  u'anti',
#  u'3000',
#  u'pitillo',
#  u'considers',
#  u'boat',
#  u'caring',
#  u'swashbuckling',
#  u'teddy',
#  u'stretch',
#  u'mounting',
#  u'vacation',
#  u'needlessly',
#  u'motives',
#  u'crawford',
#  u'wants',
#  u'tomei',
#  u'chan',
#  u'thousand',
#  u'formed',
#  u'photos',
#  u'psychotherapy',
#  u'wherewithal',
#  u'profane',
#  u'entrepenaur',
#  u'newspaper',
#  u'situation',
#  u'endured',
#  u'stupidest',
#  u'unlikeable',
#  u'shepard',
#  u'brow',
#  u'dubious',
#  u'menancing',
#  u'engages',
#  u'demolition',
#  u'fame',
#  u'missiles',
#  u'ingrained',
#  u'threatens',
#  u'perpetually',
#  u'surveillance',
#  u'songwriter',
#  u'jessalyn',
#  u'breakdown',
#  u'visually',
#  u'barbed',
#  u'edged',
#  u'hideaway',
#  u'thugs',
#  u'tolan',
#  u'barbet',
#  u'harris',
#  u'amuck',
#  u'recapture',
#  u'rain',
#  u'tracking',
#  u'pacing',
#  u'costs',
#  u'bastardizing',
#  u'dimension',
#  u'summer',
#  u'morons',
#  u'recycles',
#  u'rest',
#  u'recycled',
#  u'waitresses',
#  u'adroit',
#  u'overthrow',
#  u'sprockets',
#  u'dicks',
#  u'skies',
#  u'unveil',
#  u'dark',
#  u'traffic',
#  u'pop',
#  u'transcended',
#  u'world',
#  u'bravery',
#  u'meaning',
#  u'amputation',
#  u'clad',
#  u'discarded',
#  u'clay',
#  u'claw',
#  u'clap',
#  u'underweight',
#  u'pushy',
#  u'demeaning',
#  u'strindberg',
#  u'endeavor',
#  u'composers',
#  u'memories',
#  u'noon',
#  u'exit',
#  u'mosley',
#  u'refer',
#  u'unsuccessfully',
#  u'destroys',
#  u'contingent',
#  ...]
