# %%
import requests

# %%
response = requests.get('http://127.0.0.1:5000/')
print response.text
# Out:
# It's alive!!!

# %%
response = requests.post('http://127.0.0.1:5000/predict',
                         json={'example': [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]})

# %%
print response.json()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-66d4295c05df> in <module>()
# ----> 1 print response.json()
#
# /usr/local/lib/python2.7/site-packages/requests/models.pyc in json(self, **kwargs)
#     800                     # used.
#     801                     pass
# --> 802         return json.loads(self.text, **kwargs)
#     803
#     804     @property
#
# /usr/local/Cellar/python/2.7.9/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     336             parse_int is None and parse_float is None and
#     337             parse_constant is None and object_pairs_hook is None and not kw):
# --> 338         return _default_decoder.decode(s)
#     339     if cls is None:
#     340         cls = JSONDecoder
#
# ...
