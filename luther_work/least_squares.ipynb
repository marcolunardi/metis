# %%
import numpy as np
numbers = [2, 7, 1, 5, 10]
print mean(numbers)
candidate = np.arange(0, 10.1, 0.1)
results = []

for n in candidate:
    results.append(sum([(num - n)**2 for num in numbers]))

min(results)
# %pylab inline
plot(candidate,results)
# Out:
# 5.0
# Populating the interactive namespace from numpy and matplotlib

# %%
# Out:
# 54.0

# %%
print results
# Out:
# [179.0, 174.05000000000001, 169.20000000000002, 164.44999999999999, 159.79999999999998, 155.25, 150.80000000000001, 146.44999999999999, 142.19999999999999, 138.04999999999998, 134.0, 130.05000000000001, 126.20000000000002, 122.44999999999999, 118.79999999999998, 115.25, 111.80000000000001, 108.45000000000002, 105.2, 102.05, 99.0, 96.050000000000011, 93.199999999999989, 90.449999999999989, 87.799999999999997, 85.25, 82.800000000000011, 80.450000000000003, 78.199999999999989, 76.049999999999997, 74.0, 72.050000000000011, 70.199999999999989, 68.449999999999989, 66.799999999999997, 65.25, 63.800000000000011, 62.449999999999996, 61.199999999999989, 60.049999999999997, 59.0, 58.049999999999997, 57.200000000000003, 56.450000000000003, 55.799999999999997, 55.25, 54.799999999999997, 54.450000000000003, 54.199999999999996, 54.049999999999997, 54.0, 54.050000000000004, 54.200000000000003, 54.450000000000003, 54.800000000000004, 55.25, 55.799999999999997, 56.450000000000003, 57.200000000000003, 
# ...

# %%
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
results == 54.0
# Out:
# False

# %%
54.0 in results
# Out:
# True

# %%
results.index(54.0) * 0.1
# Out:
# 5.0
