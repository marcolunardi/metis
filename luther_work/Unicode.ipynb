# %%
"¯\_(ツ)_/¯"
# Out:
# '\xc2\xaf\\_(\xe3\x83\x84)_/\xc2\xaf'

# %%
print "¯\_(ツ)_/¯"
# Out:
# ¯\_(ツ)_/¯

# %%
type("¯\_(ツ)_/¯")
# Out:
# str

# %%
len("¯\_(ツ)_/¯")
# Out:
# 13

# %%
u"¯\_(ツ)_/¯"
# Out:
# u'\xaf\\_(\u30c4)_/\xaf'

# %%
type(u"¯\_(ツ)_/¯")
# Out:
# unicode

# %%
len(u"¯\_(ツ)_/¯")
# Out:
# 9

# %%
"¯\_(ツ)_/¯".encode('ascii')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-8-87c64c4243c7> in <module>()
# ----> 1 "¯\_(ツ)_/¯".encode('ascii')
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc2 in position 0: ordinal not in range(128)

# %%
"¯\_(ツ)_/¯".encode('utf-8')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-9-6d251deb394f> in <module>()
# ----> 1 "¯\_(ツ)_/¯".encode('utf-8')
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc2 in position 0: ordinal not in range(128)

# %%
u"¯\_(ツ)_/¯".encode('utf-8')
# Out:
# '\xc2\xaf\\_(\xe3\x83\x84)_/\xc2\xaf'

# %%
'\xc2\xaf\\_(\xe3\x83\x84)_/\xc2\xaf'.decode('utf')
# Out:
# u'\xaf\\_(\u30c4)_/\xaf'

# %%
from bs4 import BeautifulSoup

# %%
print BeautifulSoup("I &#9829; NY").text
# Out:
# I ♥ NY

# %%
print BeautifulSoup("I&nbsp;&#9829; NY").text
# non regular space, doesn't match with previous
# Out:
# I ♥ NY

# %%
from __future__ import unicode_literals

# %%
"asdf"
# Out:
# u'asdf'

# %%
print "asdf"
# Out:
# asdf
